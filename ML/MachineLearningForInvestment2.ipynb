# %%
# Developer : Baburao Kamble (University of Nebraska-Lincoln)
# Machine Learning algorithms focused on investment applications -II

import datetime
import pandas as pd
import pandas.io.data
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.rc('figure', figsize=(8, 7))
# Out:
# u'1.4.0'

# %%
from IPython.display import Latex, HTML

Latex(r"""\begin{eqnarray}r_t = \frac{StockClose_t - StockClose_{t-1}}{StockClose_{t-1}} = \frac{StockClose_t}{StockClose_{t-1}} - 1
\end{eqnarray}""")
# Out:
# \begin{eqnarray}r_t = \frac{StockClose_t - StockClose_{t-1}}{StockClose_{t-1}} = \frac{StockClose_t}{StockClose_{t-1}} - 1
# \end{eqnarray}

# %%
StockDF = pd.io.data.get_data_yahoo(['AAPL', 'MSFT', 'GOOG', 'AMZN', 'FB'], 
                               start=datetime.datetime(2014, 1, 1), 
                               end=datetime.datetime(2015, 1, 1))['Adj Close']
StockDF.head()
rets = df.pct_change(periods=3)
pd.scatter_matrix(rets, diagonal='kde', figsize=(10, 10));
corr = rets.corr()
plt.imshow(corr, cmap='hot', interpolation='none')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns)
plt.yticks(range(len(corr)), corr.columns);

# %%
#Where to invest? Risk vs Expected Return 
plt.scatter(rets.mean(), rets.std())
plt.xlabel('Expected returns')
plt.ylabel('Risk')
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (20, -20),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        bbox = dict(boxstyle = 'round,pad=0.7', fc = 'yellow', alpha = 0.5),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))
